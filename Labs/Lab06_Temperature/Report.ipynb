# %% [markdown]
# # Lab 06: Temperature
#
# **Caden Gobat and Jade Greenberg**

# %%
import numpy as np, pandas as pd, matplotlib.pyplot as plt
R0 = 10000
T0 = 298.15
R = lambda T,B : R0*np.exp(B*(1/T - 1/T0))

# %% [markdown]
# $R = R_0 \exp(\beta(T^{-1} - T_0^{-1}))$

# %% [markdown]
# ## Part IV - warming

# %%
data = pd.read_csv("./Lab06_part4.csv",header=3,names=["t","V"])
display(data.head())
data.plot(x="t",y="V")
# Out:
#      t         V
# 0  0.0 -2.669561
# 1  1.0 -2.669561
# 2  2.0 -2.674701
# 3  3.0 -2.669561
# 4  4.0 -2.669561
# <AxesSubplot:xlabel='t'>

# %% [markdown]
# ## Part V - cooling

# %%
data = pd.read_csv("./Lab06_part5.csv",header=3,names=["t","V"])
display(data.head())
data.plot(x="t",y="V")
# Out:
#      t         V
# 0  0.0 -2.690122
# 1  1.0 -2.684982
# 2  2.0 -2.695263
# 3  3.0 -2.705544
# 4  4.0 -2.720965
# <AxesSubplot:xlabel='t'>

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=385eace9-e066-4866-bb55-3a1ff5bdb476' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
